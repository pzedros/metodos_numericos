# %% [markdown]
# <a href="https://colab.research.google.com/github/pzedros/metodos_numericos/blob/main/Aula_5_otimiza%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 22/04

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

def f(x):
    return -((x**2)/10) + 2 * np.sin(x)

# Número de casas decimais desejadas
n = 6

# Critério de parada
Eppara = 0.5 * (10 ** (2 - n))

# Estimativa do erro
epest = 100

# Pontos iniciais
x1 = 0
x2 = 1
x3 = 4

xnew = 0
xold = 0

x4old = x2 - (0.5 * (((x2 - x1)**2) * (f(x2) - f(x3)) - ((x2 - x3)**2) * (f(x2) - f(x1))) /
             (((x2 - x1) * (f(x2) - f(x3)) - (x2 - x3) * (f(x2) - f(x1)))))

while epest >= Eppara:
    if f(x4old) > f(x2):
        x1 = x2
        x2 = x4old
    else:
        x3 = x2
        x2 = x4old

    x4new = x2 - (0.5 * (((x2 - x1)**2) * (f(x2) - f(x3)) - ((x2 - x3)**2) * (f(x2) - f(x1))) /
                 (((x2 - x1) * (f(x2) - f(x3)) - (x2 - x3) * (f(x2) - f(x1)))))

    x4old = x4new
    epest = abs((x4new - xold) / x4new) * 100
    xold = x4new
    print(x4new)
    print(x4old,epest)
    x=np.linspace(0,4,100)
    plt.plot(x,f(x))
    plt.plot(x4new,f(x4new),'ro')
# Out:
# 1.4902527508500856
# 1.4902527508500856 100.0
# 1.3908075360476304
# 1.3908075360476304 7.150178024276214
# 1.4212014489382157
# 1.4212014489382157 2.138606945081053
# 1.4374842819459015
# 1.4374842819459015 1.1327312035470758
# 1.4275473646739416
# 1.4275473646739416 0.6960831926042277
# 1.4275504100829388
# 1.4275504100829388 0.00021333110030260553
# 1.4275517795625838
# 1.4275517795625838 9.59320470630378e-05
# 1.4275517788976004
# 1.4275517788976004 4.6582086303762526e-08

# %% [markdown]
# Exemplo 4 - Aula 25/05

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from scipy import optimize

def f(x):
    return ((x**2)/10) - (2 *( np.sin(x)))
xmin=0
xmax=4

xopt=optimize.fminbound(f,xmin,xmax)

print(xopt)
# Out:
# 1.4275517992922275

# %% [markdown]
# Exemplo de Curva de nivel

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from scipy import optimize

x1=np.linspace(-2,0,100)
x2=np.linspace(0,3,100)

#criando as combinações de x1 e x2 usando mesghrid
X1,X2=np.meshgrid(x1,x2)

#calcula os valores da função f(x1,x2) para cada par de pontos X1,X2
Z=2+X1-X2+2*X1**2+2*X1*X2+X2**2

#curva de nivel
plt.contour(X1,X2,Z,)

# %%
#grafico de superficie
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(121, projection='3d')
cs = ax.plot_surface(X1, X2, Z, cmap='magma')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

# Definindo a função
def f(x):
  x1[0]
  x2[1]
    return 2 + x1-x2+ (2*(x1**2)) + (2*x1*x2) + (x2**2)

# Intervalo das variáveis
x1 = np.linspace(-2, 0, 100)
x2 = np.linspace(0, 3, 100)
x0=np.linspace[0,0]

xopt=optimize.minimize(f,x0)
